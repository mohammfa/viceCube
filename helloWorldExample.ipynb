# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import urllib.request as ur

import numpy as np
import tensorflow as tf

# Data sets
IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

def main():
    # If the training and test sets aren't stored locally, download them.
    if not os.path.exists(IRIS_TRAINING):
        raw = ur.urlopen(IRIS_TRAINING_URL).read()
        with open(IRIS_TRAINING, "wb") as f:
          f.write(raw)

    if not os.path.exists(IRIS_TEST):
        raw = ur.urlopen(IRIS_TEST_URL).read()
        with open(IRIS_TEST, "wb") as f:
            f.write(raw)

    # Load datasets.
    training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename=IRIS_TRAINING,
        target_dtype=np.int,
        features_dtype=np.float32)
    test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename=IRIS_TEST,
        target_dtype=np.int,
        features_dtype=np.float32)

    # Specify that all features have real-value data
    feature_columns = [tf.feature_column.numeric_column("x", shape=[4])]

    # Build 3 layer DNN with 10, 20, 10 units respectively.
    classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns,
                                          hidden_units=[10, 20, 10],
                                          n_classes=3,
                                          model_dir="/tmp/iris_model")
    
    print(training_set.data.shape)
    print(training_set.target.shape)
    print(type(np.array(training_set.data)))
    print(type(np.array(training_set.target)))
    

    # Define the training inputs
    train_input_fn = tf.estimator.inputs.numpy_input_fn(
        x={"x": np.array(training_set.data)},
        y=np.array(training_set.target),
        num_epochs=None,
        shuffle=True)

    # Train model.
    
    classifier.train(input_fn=train_input_fn, steps=2000)
    print("\n\n\n\n\n\n")


    # Define the test inputs
    test_input_fn = tf.estimator.inputs.numpy_input_fn(
        x={"x": np.array(test_set.data)},
        y=np.array(test_set.target),
        num_epochs=1,
        shuffle=False)

    # Evaluate accuracy.
    accuracy_score = classifier.evaluate(input_fn=test_input_fn)["accuracy"]
    print("\n\n\n\n\n\n")
    print(test_input_fn)
    print(type(test_input_fn))
    print(accuracy_score)
    print(type(accuracy_score))
    print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

    # Classify two new flower samples.
    new_samples = np.array(
        [[6.4, 3.2, 4.5, 1.5],
         [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)
    predict_input_fn = tf.estimator.inputs.numpy_input_fn(
        x={"x": new_samples},
        num_epochs=1,
        shuffle=False)

    predictions = list(classifier.predict(input_fn=predict_input_fn))
    predicted_classes = [p["classes"] for p in predictions]

    print(
        "New Samples, Class Predictions:    {}\n"
        .format(predicted_classes))
    print("hello")

if __name__ == "__main__":
    main()
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/iris_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c1fdf6198>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# (120, 4)
# (120,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 5.0182686, step = 2001
# INFO:tensorflow:global_step/sec: 610.448
# INFO:tensorflow:loss = 2.7511647, step = 2101 (0.165 sec)
# INFO:tensorflow:global_step/sec: 827.685
# INFO:tensorflow:loss = 9.519094, step = 2201 (0.121 sec)
# INFO:tensorflow:global_step/sec: 805.957
# INFO:tensorflow:loss = 6.110198, step = 2301 (0.124 sec)
# INFO:tensorflow:global_step/sec: 886.337
# INFO:tensorflow:loss = 1.2591531, step = 2401 (0.113 sec)
# INFO:tensorflow:global_step/sec: 905.821
# INFO:tensorflow:loss = 1.6121008, step = 2501 (0.110 sec)
# INFO:tensorflow:global_step/sec: 933.682
# INFO:tensorflow:loss = 5.215034, step = 2601 (0.107 sec)
# INFO:tensorflow:global_step/sec: 918.072
# INFO:tensorflow:loss = 3.9180038, step = 2701 (0.109 sec)
# INFO:tensorflow:global_step/sec: 857.308
# INFO:tensorflow:loss = 7.285652, step = 2801 (0.117 sec)
# INFO:tensorflow:global_step/sec: 788.141
# INFO:tensorflow:loss = 5.086385, step = 2901 (0.127 sec)
# INFO:tensorflow:global_step/sec: 780.574
# INFO:tensorflow:loss = 3.3644915, step = 3001 (0.128 sec)
# INFO:tensorflow:global_step/sec: 906.906
# INFO:tensorflow:loss = 0.74036896, step = 3101 (0.110 sec)
# INFO:tensorflow:global_step/sec: 893.502
# INFO:tensorflow:loss = 7.236231, step = 3201 (0.112 sec)
# INFO:tensorflow:global_step/sec: 857.605
# INFO:tensorflow:loss = 4.698726, step = 3301 (0.117 sec)
# INFO:tensorflow:global_step/sec: 911.278
# INFO:tensorflow:loss = 2.0502396, step = 3401 (0.110 sec)
# INFO:tensorflow:global_step/sec: 923.191
# INFO:tensorflow:loss = 4.8021135, step = 3501 (0.108 sec)
# INFO:tensorflow:global_step/sec: 976.466
# INFO:tensorflow:loss = 2.3582966, step = 3601 (0.103 sec)
# INFO:tensorflow:global_step/sec: 980.296
# INFO:tensorflow:loss = 7.054002, step = 3701 (0.102 sec)
# INFO:tensorflow:global_step/sec: 868.251
# INFO:tensorflow:loss = 5.2888904, step = 3801 (0.115 sec)
# INFO:tensorflow:global_step/sec: 838.904
# INFO:tensorflow:loss = 4.6297293, step = 3901 (0.119 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.89383936.
#
#
#
#
#
#
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-19:28:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-09-19:28:28
# INFO:tensorflow:Saving dict for global step 4000: accuracy = 0.96666664, average_loss = 0.055914775, global_step = 4000, loss = 1.6774433
#
#
#
#
#
#
#
# <function numpy_input_fn.<locals>.input_fn at 0x1c1fe78840>
# <class 'function'>
# 0.96666664
# <class 'numpy.float32'>
#
# Test Accuracy: 0.966667
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# New Samples, Class Predictions:    [array([b'1'], dtype=object), array([b'1'], dtype=object)]
#
# hello
